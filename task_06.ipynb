# %% [markdown]
# # Optional Task 6 - Bonus
#         NOTEBOOK: task_06.ipynb
#         NAME: Kristen Finley
#         DATE: 14Feb2023

# %%
import pandas as pd
import csv

# %% [markdown]
# ### CSV file General Information:
#
#     Name:'core/Batting.csv'
#
#     Contains statisitcal batting data per season for all MLB players from 1871 to 2022 represented as rows
#
#     The columns listed are as follow: "playerID,yearID,stint,teamID,lgID,G,AB,R,H,2B,3B,HR,RBI,SB,CS,BB,SO,IBB,HBP,SH,SF,GIDP"
#
#     Source: "Baseball Databank is a compilation of historical baseball data in a convenient, tidy format, distributed under Open Data terms. This work is licensed by Chadwick Baseball Bureau under the Creative Commons Attribution-ShareAlike 3.0 Unported License. For details see http://creativecommons.org/licenses/by-sa/3.0/"
#
#
# 1. Starts a new notebook.
# 2. Locates a unique csv dataset.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/chadwickbureau/baseballdatabank/master/core/Batting.csv', index_col=0)

# %% [markdown]
# ### Imported CSV as a DataFrame, showing only the last 20 rows.
#
# 3. Uses pandas to import the csv dataset into a DataFrame.

# %%
df.tail(20)
# Out:
#            yearID  stint teamID lgID    G   AB   R    H  2B  3B  ...  RBI  SB  \
# playerID                                                         ...
# yateski01    2022      1    ATL   NL    9    0   0    0   0   0  ...    0   0
# yelicch01    2022      1    MIL   NL  154  575  99  145  25   4  ...   57  19
# yepezju01    2022      1    SLN   NL   76  253  27   64  13   0  ...   30   0
# ynoahu01     2022      1    ATL   NL    2    0   0    0   0   0  ...    0   0
# youngal01    2022      1    CLE   AL    1    0   0    0   0   0  ...    0   0
# youngal01    2022      2    SFN   NL   24    0   0    0   0   0  ...    0   0
# youngda02    2022      1    SEA   AL    2    0   0    0   0   0  ...    0   0
# youngda02    2022      2    ATL   NL    1    0   0    0   0   0  ...    0   0
# youngja02    2022      1    CHN   NL    6   19   2    5   2   0  ...    0   1
# zabalan01    2022      1    MIA   NL    2    0   0    0   0   0  ...    0   0
# ...

# %% [markdown]
# ### Data 'cleaned'
#     shows columns for Player ID, Year, Team, Games, At Bats, Runs, Hits, Home Runs, and RBIs, rounded to a whole number. Only last 20 rows displayed.
#
# 4. Uses the DataFrame commands to clean the data as needed and/or rename the columns.

# %%
new_df = df.iloc[:,[0,2,3,4,5,6,7,10,11]]
pd.set_option('display.float_format', '{:.0f}'.format)
new_df.tail(20)
# Out:
#            yearID teamID lgID    G   AB   R    H  HR  RBI
# playerID
# yateski01    2022    ATL   NL    9    0   0    0   0    0
# yelicch01    2022    MIL   NL  154  575  99  145  14   57
# yepezju01    2022    SLN   NL   76  253  27   64  12   30
# ynoahu01     2022    ATL   NL    2    0   0    0   0    0
# youngal01    2022    CLE   AL    1    0   0    0   0    0
# youngal01    2022    SFN   NL   24    0   0    0   0    0
# youngda02    2022    SEA   AL    2    0   0    0   0    0
# youngda02    2022    ATL   NL    1    0   0    0   0    0
# youngja02    2022    CHN   NL    6   19   2    5   0    0
# zabalan01    2022    MIA   NL    2    0   0    0   0    0
# zastrro01    2022    NYN   NL    1    0   0    0   0    0
# zastrro01    2022    LAA   AL    5    0   0    0   0    0
# zavalse01    2022    CHA   AL   61  178  22   48   2   21
# zerpaan01    2022    KCA   AL    3    0   0    0   0    0
# zeuchtj01    2022    CIN   NL    3    0   0    0   0    0
# ...

# %% [markdown]
# ### Descriptive Statistics for all 'cleaned' data.
#     The Range of RBIs for all players is 0-191, with the upper quartile only at 24.
#
# 5. Uses the DataFrame describe() function to calculate basic descriptive statistics.

# %%
new_df.describe()
# Out:
#        yearID      G     AB      R      H     HR    RBI
# count  112184 112184 112184 112184 112184 112184 111428
# mean     1969     50    138     18     36      3     17
# std        40     47    183     28     52      6     26
# min      1871      1      0      0      0      0      0
# 25%      1938     12      3      0      0      0      0
# 50%      1978     34     45      4      8      0      3
# 75%      2003     78    221     26     55      2     24
# max      2022    165    716    198    262     73    191

# %% [markdown]
# ### BEST MLB BATTERS (RBI > 100)
#     Assessing at the RBI statistics of the previous table, an abbitrary RBI value of '100' is assigned to generate a table representing "the best" batters of the MLB each season.
#
# 5. (continued) Uses the DataFrame describe() function to calculate basic descriptive statistics.

# %%
df_rbi100 = new_df.loc[new_df['RBI'] > 100]
df_rbi100.describe()
# Out:
#        yearID    G   AB    R    H   HR  RBI
# count    1833 1833 1833 1833 1833 1833 1833
# mean     1968  149  567  100  173   28  115
# std        38   11   48   18   23   12   13
# min      1884  102  373   45  113    0  101
# 25%      1937  144  537   87  157   21  105
# 50%      1977  152  571   98  172   30  111
# 75%      2000  157  601  111  188   37  121
# max      2022  164  696  177  257   73  191

# %% [markdown]
# ### BEST STL BATTERS (RBI>100)
#     But what if I only care about the St. Louis Cardinals? Well, you are in luck! Here is another dataframe that describes the statistics for the "best" Redbird batters each season.
#
#     St. Louis only had 91 of the 1833 players get 100 RBIs... that's only about ~5%. Whah Whah.

# %%
stl_rbi100 = df_rbi100.loc[df_rbi100['teamID'] == 'SLN']
stl_rbi100.describe()
# Out:
#        yearID   G  AB   R   H  HR  RBI
# count      91  91  91  91  91  91   91
# mean     1965 151 569 101 182  28  115
# std        31   9  47  19  25  11   13
# min      1899 120 419  60 120   8  101
# 25%      1938 148 534  90 163  20  104
# 50%      1957 153 577 100 180  27  111
# 75%      1998 157 602 116 196  34  124
# max      2022 162 658 141 250  70  154

# %% [markdown]
# 6. Use the DataFrame hist() function to generate histograms for all numeric columns.

# %%
histogram = new_df.hist()
